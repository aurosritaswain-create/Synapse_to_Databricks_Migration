# %%
from pyspark.sql.functions import col, upper
#1. Read from the Bronze tables we just created
df_json_bronze = spark.read.table("bronze_json_data") 
df_csv_bronze = spark.read.table("bronze_csv_data")

#2. Clean JSON: Filter out null transactions
df_json_silver = df_json_bronze.filter(col("transaction_id").isNotNull())

#3. Clean CSV: Create uppercase column and filter nulls
df_csv_silver = (
    df_csv_bronze
    .withColumn("department_upper", upper(col("department")))
    .filter(col("transaction_id").isNotNull())
)

#4. Save as Silver Delta Tables
df_json_silver.write.format("delta").mode("overwrite").saveAsTable("silver_json_data")
df_csv_silver.write.format("delta").mode("overwrite").saveAsTable("silver_csv_data")

print("Silver transformations complete!")
# Out:
# Silver transformations complete!

# %%
# %sql
SELECT *FROM silver_csv_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_id</th><th>retailer</th><th>store_location</th><th>department</th><th>project_type</th><th>sku</th><th>brand</th><th>unit_price</th><th>quantity</th><th>bulk_discount_applied_%</th><th>subtotal_before_discount</th><th>total_after_discount</th><th>pro_program</th><th>purchase_date</th><th>department_upper</th></tr></thead><tbody><tr><td>DO-20240910-11568</td><td>Do it Best</td><td>South Joyceburgh, AS</td><td>Electrical</td><td>Electrical Upgrade</td><td>ELE-382095</td><td>Behr</td><td>187.31</td><td>20</td><td>5</td><td>3746.2</td><td>3558.89</td><td>Contractors' Warehouse CBC</td><td>2024-09-10T02:15:59.000Z</td><td>ELECTRICAL</td></tr><tr><td>LOW-20241106-63550</td><td>Lowe's</td><td>New Scott, MS</td><td>Drywall & Insulation</td><td>Electrical Upgrade</td><td>DRY-123851</td><td>Philips</td><td>29.88</td><td>75</td><td>15</td><td>2241.0</td><td>1904.85</td><td>Lowe's MVPs Pro Rewards</td><td>2024-11-06T07:02:37.000Z</td><td>DRYWALL & INSULATION</td></tr><tr><td>HAR-20240516-41194</td><td>Harbor Freight Tools</td><td>North David, TX</td><td>null</td><td>Drywall Patch</td><td>ELE-160787</td><td>null</td><td>497.18</td><td>60</td><td>25</td><td>29830.8</td><td>22373.1</td><td>Contractors' Warehouse CBC</td><td>2024-05-16T12:50:33.000Z</td><td>null</td></tr><tr><td>LOW-20241110-17341</td><td>Lowe's</td><td>Floresfort, AK</td><td>Outdoor & Garden</td><td>Landscaping</td><td>OUT-878292</td><td>Makita</td><td>155.18</td><td>10</td><td>15</td><td>1551.8</td><td>1319.03</td><td>Ace Rewards</td><td>2024-11-10T05:37:10.000Z</td><td>OUTDOOR & GARDEN</td></tr><tr><td>HAR-20240724-68170</td><td>Harbor Freight Tools</td><td>North Margaretside, IL</td